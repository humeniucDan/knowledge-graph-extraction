# %%
import torch
torch.cuda.is_available()
# Out:
# True

# %%
import cupy
cupy.cuda
# Out:
# <module 'cupy.cuda' from '/home/dan/Work/utcn/an4/sem1/pso/proj/knowledge-graph-extraction/.venv1/lib/python3.11/site-packages/cupy/cuda/__init__.py'>

# %%
cupy.cuda.Device(0).use()
import spacy
spacy.prefer_gpu()
# Out:
# True

# %%
nlp = spacy.load('en_core_web_trf', disable=['parser', 'ner', 'laminiser'])

# %%
doc = nlp("I read a book while I book a table.")
print([(token.text, token.pos_) for token in doc])
# Out:
# [('I', ''), ('read', ''), ('a', ''), ('book', ''), ('while', ''), ('I', ''), ('book', ''), ('a', ''), ('table', ''), ('.', '')]
